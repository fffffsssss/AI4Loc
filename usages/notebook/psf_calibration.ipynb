# %% [markdown]
# # PSF calibration notebook
# To use this notebook you don't need to interact with any code, just run cells in order and a graphical user interface will pop-up showcasing the parameters for each step.

# %%
from IPython.display import display
import sys
sys.path.append('../../')
import ailoc.common

# %matplotlib inline

# %% [markdown]
# ## 1. Select the bead stack file and set the parameters

# %%
calib_widget = ailoc.common.BeadsCalibrationWidget()
calib_widget.display_notebook_gui()
# Out:
# Button(description='Select the tiff file to calibrate', icon='square-o', layout=Layout(height='80px', width='1…
# GridspecLayout()
# Label(value='PSF parameters', style=LabelStyle(font_weight='bold'))
# SetPSFParamWidget(children=(BoundedFloatText(value=1.5, description='NA:', layout=Layout(grid_area='widget001'…
# Label(value='Camera parameters', style=LabelStyle(font_weight='bold'))
# Dropdown(description='CameraType:', index=1, options=('Idea Camera', 'sCMOS', 'EMCCD'), value='sCMOS')
# GridspecLayout(children=(sCMOSParamWidget(children=(BoundedFloatText(value=0.81, description='QE:', layout=Lay…
# CalibParamWidget(children=(Label(value='Calibration parameters', layout=Layout(grid_area='widget001'), style=L…
# Button(description='Set Parameters', style=ButtonStyle())
# Output()

# %% [markdown]
# ## 2. Run the code cell to do the calibration

# %%
calib_widget.run()
# Out:
# iter:0, nll:2451683.0
# iter:1, nll:844226.5
# iter:2, nll:738836.75
# iter:3, nll:735520.0
# iter:4, nll:735198.0
# iter:5, nll:735186.0
# iter:6, nll:735185.875
# iter:7, nll:735185.875
# the fitting time is: 9.489607572555542s
# the relative root of squared error is: 23.714181780815125%
# [ 2.000 -2.000]: 57.368064880371094
# [ 2.000  2.000]: 9.9392728805542
# [ 3.000 -1.000]: -29.72852325439453
# [ 3.000  1.000]: 10.373270034790039
# [ 4.000  0.000]: 32.210105895996094
# [ 3.000 -3.000]: -7.210447311401367
# [ 3.000  3.000]: -7.057523727416992
# [ 4.000 -2.000]: -26.01738166809082
# [ 4.000  2.000]: -16.97890281677246
# [ 5.000 -1.000]: 8.993036270141602
# [ 5.000  1.000]: 12.43380069732666
# [ 6.000  0.000]: 40.2911262512207
# [ 4.000 -4.000]: -1.7452770471572876
# [ 4.000  4.000]: 4.307657718658447
# [ 5.000 -3.000]: 2.864727735519409
# [ 5.000  3.000]: -2.978801727294922
# [ 6.000 -2.000]: 12.747220993041992
# [ 6.000  2.000]: -1.0694509744644165
# [ 7.000  1.000]: 6.135223865509033
# [ 7.000 -1.000]: 3.137943744659424
# [ 8.000  0.000]: 27.091453552246094
# the calibration results are saved in: D:/Li_Lab_users/fushuang/AI4Loc-master/datasets/demo2-exp_npc_dmo1.2/beads_step20/1_calib_results.mat
