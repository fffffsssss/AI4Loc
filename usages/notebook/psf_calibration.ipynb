# %% [markdown]
# # Zernike calibration notebook
# To use this notebook you don't need to interact with any code, just run cells in order and a graphical user interface will pop-up showcasing the parameters for each step.

# %%
from IPython.display import display
import sys
sys.path.append('../../')
import ailoc.common

# %matplotlib inline

# %% [markdown]
# ## 1. Select the bead stack file and set the parameters

# %%
calib_widget = ailoc.common.BeadsCalibrationWidget()
calib_widget.display_notebook_gui()
# Out:
# Button(description='Select the tiff file to calibrate', icon='square-o', layout=Layout(height='80px', width='1…
# GridspecLayout()
# Label(value='PSF parameters', style=LabelStyle(font_weight='bold'))
# SetPSFParamWidget(children=(BoundedFloatText(value=1.5, description='NA:', layout=Layout(grid_area='widget001'…
# Label(value='Camera parameters', style=LabelStyle(font_weight='bold'))
# Dropdown(description='CameraType:', index=1, options=('Idea Camera', 'sCMOS', 'EMCCD'), value='sCMOS')
# GridspecLayout(children=(sCMOSParamWidget(children=(BoundedFloatText(value=0.81, description='QE:', layout=Lay…
# CalibParamWidget(children=(Label(value='Calibration parameters', layout=Layout(grid_area='widget001'), style=L…
# Button(description='Set Parameters', style=ButtonStyle())
# Output()

# %% [markdown]
# ## 2. Run the code cell to do the calibration

# %%
calib_widget.run()
# Out:
# iter:0, nll:2634157.75
# iter:1, nll:975446.5
# iter:2, nll:855684.375
# iter:3, nll:853267.5
# iter:4, nll:853183.625
# iter:5, nll:853183.25
# iter:6, nll:853183.25
# the fitting time is: 8.412219524383545s
# the relative root of squared error is: 23.954297602176666%
# [ 2.000 -2.000]: 57.25141525268555
# [ 2.000  2.000]: 9.445988655090332
# [ 3.000 -1.000]: -29.26011848449707
# [ 3.000  1.000]: 11.229180335998535
# [ 4.000  0.000]: 31.721521377563477
# [ 3.000 -3.000]: -7.128249645233154
# [ 3.000  3.000]: -6.159634113311768
# [ 4.000 -2.000]: -25.831396102905273
# [ 4.000  2.000]: -17.297344207763672
# [ 5.000 -1.000]: 9.249943733215332
# [ 5.000  1.000]: 13.298287391662598
# [ 6.000  0.000]: 39.67202377319336
# [ 4.000 -4.000]: -2.1271040439605713
# [ 4.000  4.000]: 3.934854745864868
# [ 5.000 -3.000]: 2.9097912311553955
# [ 5.000  3.000]: -2.236100435256958
# [ 6.000 -2.000]: 13.10659408569336
# [ 6.000  2.000]: -0.9783757925033569
# [ 7.000  1.000]: 6.059555530548096
# [ 7.000 -1.000]: 3.2232651710510254
# [ 8.000  0.000]: 27.462757110595703
# the calibration results are saved in: E:/projects/FS_work/AI4Loc_FS/AI4Loc/datasets/demo2-exp_npc_dmo1.2/beads_step20/1_calib_results.mat
