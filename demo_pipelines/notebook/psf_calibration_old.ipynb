# %% [markdown]
# # Zernike calibration notebook
# To use this notebook you don't need to interact with any code, just run cells in order and a graphical user interface will pop-up showcasing the parameters for each step.

# %%
from IPython.display import display
import sys
sys.path.append('../../')
import ailoc.common

# %matplotlib inline

# %% [markdown]
# ## 1. Select the bead stack file and set the parameters

# %%
calib_widget = ailoc.common.BeadsCalibrationWidget()
calib_widget.display_notebook_gui()
# Out:
# SelectFilesButtonShow(children=(Button(description='Select the tiff file to calibrate', icon='square-o', layou…
# ZernikeFitParamWidget(children=(Label(value='Peak finding parameters', layout=Layout(grid_area='widget001')), …
# Output()

# %% [markdown]
# ## 2. Run the code cell to do the calibration

# %%
calib_widget.run()
# Out:
# E:\projects\FS_work\AI-Loc\AI-Loc_project\ailoc\common\beads_calibration\interp_cubic_convolution.py:150: NumbaPerformanceWarning: np.dot() is faster on contiguous arrays, called on (Array(float64, 1, 'C', False, aligned=True), Array(float64, 2, 'A', False, aligned=True))
#   retV[ii1*2**k+jj1,ii2*2**k+jj2] = np.vdot(np.dot(K1,Vext[ii1:(ii1+4),ii2:(ii2+4)]),K2)
# E:\projects\FS_work\AI-Loc\AI-Loc_project\ailoc\common\beads_calibration\interp_cubic_convolution.py:74: NumbaPerformanceWarning: np.vdot() is faster on contiguous arrays, called on (Array(float64, 1, 'C', False, aligned=True), Array(float64, 1, 'A', False, aligned=True))
#   retV[ii*2**k+jj,iii] = np.vdot(K,Vext[ii:(ii+4),iii])
# ROBUSTMEAN:INSUFFICIENTDATA Less than 4 data points!
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 np.nanstd(data,[],dim)
#
# File <__array_function__ internals>:200, in nanstd(*args, **kwargs)
#
# File D:\Softwares\anaconda3\envs\ailoc\lib\site-packages\numpy\lib\nanfunctions.py:1872, in nanstd(a, axis, dtype, out, ddof, keepdims, where)
#    1771 @array_function_dispatch(_nanstd_dispatcher)
#    1772 def nanstd(a, axis=None, dtype=None, out=None, ddof=0, keepdims=np._NoValue,
#    1773            *, where=np._NoValue):
#    1774     """
#    1775     Compute the standard deviation along the specified axis, while
#    1776     ignoring NaNs.
#    (...)
#    1870
#    1871     """
# -> 1872     var = nanvar(a, axis=axis, dtype=dtype, out=out, ddof=ddof,
#    1873                  keepdims=keepdims, where=where)
#    1874     if isinstance(var, np.ndarray):
#    1875         std = np.sqrt(var, out=var)
#
# File <__array_function__ internals>:200, in nanvar(*args, **kwargs)
#
# File D:\Softwares\anaconda3\envs\ailoc\lib\site-packages\numpy\lib\nanfunctions.py:1712, in nanvar(a, axis, dtype, out, ddof, keepdims, where)
#    1708     return np.var(arr, axis=axis, dtype=dtype, out=out, ddof=ddof,
#    1709                   keepdims=keepdims, where=where)
#    1711 if dtype is not None:
# -> 1712     dtype = np.dtype(dtype)
#    1713 if dtype is not None and not issubclass(dtype.type, np.inexact):
#    1714     raise TypeError("If a is inexact, then dtype must be inexact")
#
# TypeError: Cannot interpret '1' as a data type
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 calib_widget.run()
#
# File E:\projects\FS_work\AI-Loc\AI-Loc_project\ailoc\common\notebook_gui.py:350, in BeadsCalibrationWidget.run(self)
#     348 parameters = self.set_param_widget.params_dict
#     349 parameters['filelist'] = [self.select_file_widget.files]
# --> 350 result = ailoc.common.beads_calibration.main_calibration.calibrate_data(parameters)
#     352 outputfile = parameters['filelist'][0] + '_' + 'calib.mat'
#     353 scio.savemat(outputfile, result)
#
# File E:\projects\FS_work\AI-Loc\AI-Loc_project\ailoc\common\beads_calibration\main_calibration.py:76, in calibrate_data(parameters)
#      72 spline_fig = None
#      74 indgoodc = np.ones(len(beadsh), dtype=bool)
# ---> 76 csplinecal, indgoods, shift, fig_list = get_stackcal_so(beadsh[indgoodc != 0], parameters)
#      77 plt.show()
#      79 icf = np.where(indgoodc)[0]
#
# File E:\projects\FS_work\AI-Loc\AI-Loc_project\ailoc\common\beads_calibration\get_stackcal_so.py:109, in get_stackcal_so(beads, p)
#     106 para['zshiftf0'] = zshift
#     107 para['beadfilterf0']=False
# --> 109 corrPSF,shiftedstack,shift,beadgood = registerPSF3D_so(allstacks,para,[],filenumber[sortinddev])
#     111 indgood=beadgood
#     112 allrois=allstacks
#
# File E:\projects\FS_work\AI-Loc\AI-Loc_project\ailoc\common\beads_calibration\registerPSF3D_so.py:51, in registerPSF3D_so(imin, p, axs, filenumber)
#      49 shiftedstackn = normalizstack(shiftedstack, p)
#      50 indgood = np.full((1,np.size(shiftedstackn,3)), True, dtype=bool)[0]
# ---> 51 indgood,res1,normamp1,co1,cc1 = getoverlap(shiftedstackn, shift, ph, indgood)
#      52 meanim = np.nanmean(shiftedstack[:,:,:,indgood],3)
#      53 meanim[np.isnan(meanim)] = avim[np.isnan(meanim)]
#
# File E:\projects\FS_work\AI-Loc\AI-Loc_project\ailoc\common\beads_calibration\registerPSF3D_so.py:107, in getoverlap(shiftedstackn, shift, p, indgood)
#     105 rescc = res/cc
#     106 rescc[np.logical_or(np.abs(shift[:,0])>3,np.abs(shift[:,1])>3)]=np.nan
# --> 107 [a,b] = robustMean([rescc[cc>0]])
#     108 if(np.isnan(b)):
#     109     a = np.nanmean(rescc)
#
# File E:\projects\FS_work\AI-Loc\AI-Loc_project\ailoc\common\beads_calibration\registerPSF3D_so.py:133, in robustMean(data, dim, k, fit)
#     131 print('ROBUSTMEAN:INSUFFICIENTDATA Less than 4 data points!')
#     132 finalMean = np.nanmean(data,dim)
# --> 133 stdSample = np.nanstd(data,[],dim)
#     134 inlierIdx = matlab_find(np.isfinite(data))
#     135 outlierIdx = []
#
# File E:\projects\FS_work\AI-Loc\AI-Loc_project\ailoc\common\beads_calibration\registerPSF3D_so.py:133, in robustMean(data, dim, k, fit)
#     131 print('ROBUSTMEAN:INSUFFICIENTDATA Less than 4 data points!')
#     132 finalMean = np.nanmean(data,dim)
# --> 133 stdSample = np.nanstd(data,[],dim)
#     134 inlierIdx = matlab_find(np.isfinite(data))
#     135 outlierIdx = []
#
# File _pydevd_bundle\pydevd_cython_win32_39_64.pyx:1179, in _pydevd_bundle.pydevd_cython_win32_39_64.SafeCallWrapper.__call__()
#
# File _pydevd_bundle\pydevd_cython_win32_39_64.pyx:620, in _pydevd_bundle.pydevd_cython_win32_39_64.PyDBFrame.trace_dispatch()
#
# File _pydevd_bundle\pydevd_cython_win32_39_64.pyx:929, in _pydevd_bundle.pydevd_cython_win32_39_64.PyDBFrame.trace_dispatch()
#
# File _pydevd_bundle\pydevd_cython_win32_39_64.pyx:920, in _pydevd_bundle.pydevd_cython_win32_39_64.PyDBFrame.trace_dispatch()
#
# File _pydevd_bundle\pydevd_cython_win32_39_64.pyx:317, in _pydevd_bundle.pydevd_cython_win32_39_64.PyDBFrame.do_wait_suspend()
#
# File D:\Softwares\PyCharm 2022.2.3\plugins\python\helpers\pydev\pydevd.py:1160, in PyDB.do_wait_suspend(self, thread, frame, event, arg, send_suspend_message, is_unhandled_exception)
#    1157         from_this_thread.append(frame_id)
#    1159 with self._threads_suspended_single_notification.notify_thread_suspended(thread_id, stop_reason):
# -> 1160     self._do_wait_suspend(thread, frame, event, arg, suspend_type, from_this_thread)
#
# File D:\Softwares\PyCharm 2022.2.3\plugins\python\helpers\pydev\pydevd.py:1175, in PyDB._do_wait_suspend(self, thread, frame, event, arg, suspend_type, from_this_thread)
#    1172             self._call_mpl_hook()
#    1174         self.process_internal_commands()
# -> 1175         time.sleep(0.01)
#    1177 self.cancel_async_evaluation(get_current_thread_id(thread), str(id(frame)))
#    1179 # process any stepping instructions
#
# KeyboardInterrupt:
