# %% [markdown]
# # Zernike calibration notebook
# To use this notebook you don't need to interact with any code, just run cells in order and a graphical user interface will pop-up showcasing the parameters for each step.

# %%
from IPython.display import display
import sys
sys.path.append('../../')
import ailoc.common

# %matplotlib inline

# %% [markdown]
# ## 1. Select the bead stack file and set the parameters

# %%
calib_widget = ailoc.common.BeadsCalibrationWidget()
calib_widget.display_notebook_gui()
# Out:
# Button(description='Select the tiff file to calibrate', icon='square-o', layout=Layout(height='80px', width='1…
# GridspecLayout()
# SetPSFParamWidget(children=(Label(value='PSF parameters', layout=Layout(grid_area='widget001')), BoundedFloatT…
# Label(value='Camera parameters')
# Dropdown(description='Camera type:', index=1, options=('Idea Camera', 'sCMOS', 'EMCCD'), value='sCMOS')
# GridspecLayout(children=(sCMOSParamWidget(children=(BoundedFloatText(value=0.9, description='QE:', layout=Layo…
# CalibParamWidget(children=(Label(value='Calibration parameters', layout=Layout(grid_area='widget001')), Bounde…
# Button(description='Set Parameters', style=ButtonStyle())
# Output()

# %% [markdown]
# ## 2. Run the code cell to do the calibration

# %%
calib_widget.run()
# Out:
# iter:0, nll:4612891.0
# iter:1, nll:1017424.6875
# iter:2, nll:978765.625
# iter:3, nll:941261.75
# iter:4, nll:941251.375
# iter:5, nll:941250.75
# iter:6, nll:941250.75
# the fitting time is: 16.32266092300415s
# the relative root of squared error is: 14.531897008419037%
# [ 2.000 -2.000]: -0.6344886422157288
# [ 2.000  2.000]: 61.501277923583984
# [ 3.000 -1.000]: -19.54088592529297
# [ 3.000  1.000]: 17.34817123413086
# [ 4.000  0.000]: 13.334077835083008
# [ 3.000 -3.000]: 1.6690844297409058
# [ 3.000  3.000]: -2.2446422576904297
# [ 4.000 -2.000]: -5.946126937866211
# [ 4.000  2.000]: -5.592281341552734
# [ 5.000 -1.000]: -2.068500518798828
# [ 5.000  1.000]: -4.244129657745361
# [ 6.000  0.000]: 28.070022583007812
# [ 4.000 -4.000]: -0.4002145528793335
# [ 4.000  4.000]: -0.23307928442955017
# [ 5.000 -3.000]: 0.20554716885089874
# [ 5.000  3.000]: 0.7497880458831787
# [ 6.000 -2.000]: -0.9672220349311829
# [ 6.000  2.000]: -4.071076393127441
# [ 7.000  1.000]: -2.2562334537506104
# [ 7.000 -1.000]: 1.0881943702697754
# [ 8.000  0.000]: 18.968935012817383
# the calibration results are saved in: E:/projects/FS_work/AI-Loc/AI-Loc_project/datasets/sw_npc_20211028/beads/astigmatism/astigmatism_beads_2um_20nm_512x512_hamm_1/astigmatism_beads_2um_20nm_512x512_hamm_1_MMStack_Default_calib_results.mat
