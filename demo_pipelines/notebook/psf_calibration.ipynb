# %% [markdown]
# # Zernike calibration notebook
# To use this notebook you don't need to interact with any code, just run cells in order and a graphical user interface will pop-up showcasing the parameters for each step.

# %%
from IPython.display import display
import sys
sys.path.append('../../')
import ailoc.common

# %matplotlib inline

# %% [markdown]
# ## 1. Select the bead stack file and set the parameters

# %%
calib_widget = ailoc.common.BeadsCalibrationWidget()
calib_widget.display_notebook_gui()
# Out:
# Button(description='Select the tiff file to calibrate', icon='square-o', layout=Layout(height='80px', width='1…
# GridspecLayout()
# Label(value='PSF parameters', style=LabelStyle(font_weight='bold'))
# SetPSFParamWidget(children=(BoundedFloatText(value=1.5, description='NA:', layout=Layout(grid_area='widget001'…
# Label(value='Camera parameters', style=LabelStyle(font_weight='bold'))
# Dropdown(description='Camera type:', index=1, options=('Idea Camera', 'sCMOS', 'EMCCD'), value='sCMOS')
# GridspecLayout(children=(sCMOSParamWidget(children=(BoundedFloatText(value=0.81, description='QE:', layout=Lay…
# CalibParamWidget(children=(Label(value='Calibration parameters', layout=Layout(grid_area='widget001'), style=L…
# Button(description='Set Parameters', style=ButtonStyle())
# Output()

# %% [markdown]
# ## 2. Run the code cell to do the calibration

# %%
calib_widget.run()
# Out:
# iter:0, nll:7389083.0
# iter:1, nll:926909.625
# iter:2, nll:910048.0625
# iter:3, nll:909326.875
# iter:4, nll:909326.875
# the fitting time is: 15.455541610717773s
# the relative root of squared error is: 13.635805249214172%
# [ 2.000 -2.000]: 80.03060150146484
# [ 2.000  2.000]: -4.965980529785156
# [ 3.000 -1.000]: -18.64044189453125
# [ 3.000  1.000]: -11.99785327911377
# [ 4.000  0.000]: -13.120319366455078
# [ 3.000 -3.000]: 4.877859592437744
# [ 3.000  3.000]: 32.0123405456543
# [ 4.000 -2.000]: -249.03932189941406
# [ 4.000  2.000]: -4.650782585144043
# [ 5.000 -1.000]: -10.490045547485352
# [ 5.000  1.000]: 4.638710975646973
# [ 6.000  0.000]: -6.88819694519043
# [ 4.000 -4.000]: -11.407517433166504
# [ 4.000  4.000]: -1.0732170343399048
# [ 5.000 -3.000]: -3.3944759368896484
# [ 5.000  3.000]: -5.353759288787842
# [ 6.000 -2.000]: -23.46184730529785
# [ 6.000  2.000]: -7.999769687652588
# [ 7.000  1.000]: 0.505204439163208
# [ 7.000 -1.000]: 2.528261184692383
# [ 8.000  0.000]: -1.036936640739441
# the calibration results are saved in: E:/projects/FS_work/AI-Loc/AI-Loc_project/datasets/fy_npc6um_1/DMO_6um_Crimson_645_beads_defoucs_0_step_100nm_1/DMO_6um_Crimson_645_beads_defoucs_0_step_100nm_1_MMStack_Pos0_calib_results.mat
